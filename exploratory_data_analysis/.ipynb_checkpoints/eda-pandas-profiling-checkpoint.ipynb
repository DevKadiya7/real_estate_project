# %%
import sys
print(sys.executable)
# Out:
# c:\Users\shivam\AppData\Local\Programs\Python\Python314\python.exe

# %%
# %pip install -U ydata-profiling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 4.0.0 Requires-Python >=3.7,<3.11; 4.1.0 Requires-Python >=3.7,<3.12; 4.1.1 Requires-Python >=3.7,<3.12; 4.1.2 Requires-Python >=3.7,<3.12; 4.10.0 Requires-Python >=3.7,<3.13; 4.11.0 Requires-Python >=3.7,<3.13; 4.12.0 Requires-Python >=3.7,<3.13; 4.12.1 Requires-Python >=3.7,<3.13; 4.12.2 Requires-Python >=3.7,<3.13; 4.13.0 Requires-Python >=3.7,<3.13; 4.14.0 Requires-Python >=3.7,<3.13; 4.15.0 Requires-Python >=3.7,<3.13; 4.15.1 Requires-Python >=3.7,<3.13; 4.16.0 Requires-Python >=3.7,<3.13; 4.16.1 Requires-Python >=3.7,<3.13; 4.17.0 Requires-Python >=3.7,<3.14; 4.18.0 Requires-Python >=3.10,<3.14; 4.18.1 Requires-Python >=3.10,<3.14; 4.18.4 Requires-Python >=3.10,<3.14; 4.2.0 Requires-Python >=3.7,<3.12; 4.3.0 Requires-Python >=3.7,<3.12; 4.3.1 Requires-Python >=3.7,<3.12; 4.3.2 Requires-Python >=3.7,<3.12; 4.4.0 Requires-Python >=3.7,<3.12; 4.5.0 Requires-Python >=3.7,<3.12; 4.5.1 Requires-Python >=3.7,<3.12; 4.6.0 Requires-Python >=3.7,<3.12; 4.6.1 Requires-Python >=3.7,<3.12; 4.6.2 Requires-Python >=3.7,<3.12; 4.6.3 Requires-Python >=3.7,<3.12; 4.6.4 Requires-Python >=3.7,<3.12; 4.6.5 Requires-Python >=3.7,<3.12; 4.7.0 Requires-Python >=3.7,<3.13; 4.8.3 Requires-Python >=3.7,<3.13; 4.9.0 Requires-Python >=3.7,<3.13
# ERROR: Could not find a version that satisfies the requirement ydata-profiling (from versions: none)
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for ydata-profiling

# %%
# %pip install --upgrade pip
# %pip install pandas
# %pip install matplotlib
# %pip install ydata-profiling
# %pip install notebook
# Out:
# Requirement already satisfied: pip in c:\users\shivam\appdata\local\programs\python\python314\lib\site-packages (25.3)
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 958.4 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.8/1.8 MB 1.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.3/1.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.2 MB/s  0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-26.1.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.14.exe and pip3.exe are installed in 'c:\Users\shivam\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Requirement already satisfied: pandas in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.0)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.2.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp314-cp314-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.5 MB 997.1 kB/s eta 0:00:09
#    -- ------------------------------------- 0.5/9.5 MB 997.1 kB/s eta 0:00:09
#    --- ------------------------------------ 0.8/9.5 MB 968.7 kB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/9.5 MB 1.1 MB/s eta 0:00:08
#    ------ --------------------------------- 1.6/9.5 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.5 MB 1.3 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.5 MB 1.3 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.5 MB 1.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 2.6/9.5 MB 1.2 MB/s eta 0:00:06
#    ------------ --------------------------- 2.9/9.5 MB 1.3 MB/s eta 0:00:06
#    ------------- -------------------------- 3.1/9.5 MB 1.3 MB/s eta 0:00:05
#    -------------- ------------------------- 3.4/9.5 MB 1.3 MB/s eta 0:00:05
#    --------------- ------------------------ 3.7/9.5 MB 1.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.5 MB 1.3 MB/s eta 0:00:04
#    ------------------ --------------------- 4.5/9.5 MB 1.3 MB/s eta 0:00:04
#    ------------------- -------------------- 4.7/9.5 MB 1.3 MB/s eta 0:00:04
#    --------------------- ------------------ 5.0/9.5 MB 1.3 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.2/9.5 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.5/9.5 MB 1.4 MB/s eta 0:00:03
#    ------------------------ --------------- 5.8/9.5 MB 1.3 MB/s eta 0:00:03
#    ------------------------ --------------- 5.8/9.5 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.3/9.5 MB 1.3 MB/s eta 0:00:03
#    --------------------------- ------------ 6.6/9.5 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.1/9.5 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 7.6/9.5 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.1/9.5 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.5 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 1.4 MB/s  0:00:06
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 1.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.7 MB/s  0:00:01
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/6 [pyparsing]
#    ------ --------------------------------- 1/6 [kiwisolver]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    -------------------- ------------------- 3/6 [cycler]
#    -------------------------- ------------- 4/6 [contourpy]
#    -------------------------- ------------- 4/6 [contourpy]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    --------------------------------- ------ 5/6 [matplotlib]
#    ---------------------------------------- 6/6 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\shivam\AppData\Local\Programs\Python\Python314\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 4.0.0 Requires-Python >=3.7,<3.11; 4.1.0 Requires-Python >=3.7,<3.12; 4.1.1 Requires-Python >=3.7,<3.12; 4.1.2 Requires-Python >=3.7,<3.12; 4.10.0 Requires-Python >=3.7,<3.13; 4.11.0 Requires-Python >=3.7,<3.13; 4.12.0 Requires-Python >=3.7,<3.13; 4.12.1 Requires-Python >=3.7,<3.13; 4.12.2 Requires-Python >=3.7,<3.13; 4.13.0 Requires-Python >=3.7,<3.13; 4.14.0 Requires-Python >=3.7,<3.13; 4.15.0 Requires-Python >=3.7,<3.13; 4.15.1 Requires-Python >=3.7,<3.13; 4.16.0 Requires-Python >=3.7,<3.13; 4.16.1 Requires-Python >=3.7,<3.13; 4.17.0 Requires-Python >=3.7,<3.14; 4.18.0 Requires-Python >=3.10,<3.14; 4.18.1 Requires-Python >=3.10,<3.14; 4.18.4 Requires-Python >=3.10,<3.14; 4.2.0 Requires-Python >=3.7,<3.12; 4.3.0 Requires-Python >=3.7,<3.12; 4.3.1 Requires-Python >=3.7,<3.12; 4.3.2 Requires-Python >=3.7,<3.12; 4.4.0 Requires-Python >=3.7,<3.12; 4.5.0 Requires-Python >=3.7,<3.12; 4.5.1 Requires-Python >=3.7,<3.12; 4.6.0 Requires-Python >=3.7,<3.12; 4.6.1 Requires-Python >=3.7,<3.12; 4.6.2 Requires-Python >=3.7,<3.12; 4.6.3 Requires-Python >=3.7,<3.12; 4.6.4 Requires-Python >=3.7,<3.12; 4.6.5 Requires-Python >=3.7,<3.12; 4.7.0 Requires-Python >=3.7,<3.13; 4.8.3 Requires-Python >=3.7,<3.13; 4.9.0 Requires-Python >=3.7,<3.13
# ERROR: Could not find a version that satisfies the requirement ydata-profiling (from versions: none)
# ERROR: No matching distribution found for ydata-profiling

# %%
import sys
print(sys.executable)

# !{sys.executable} -m pip --version
# !{sys.executable} -m pip show ydata-profiling
# Out:
# c:\Users\shivam\AppData\Local\Programs\Python\Python314\python.exe
# pip 25.3 from c:\Users\shivam\AppData\Local\Programs\Python\Python314\Lib\site-packages\pip (python 3.14)
# WARNING: Package(s) not found: ydata-profiling

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('../cleaned_datasets/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("output_report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       3
#       4 # Load your dataset
#       5 df = pd.read_csv('../cleaned_datasets/gurgaon_properties_cleaned_v2.csv').drop_duplicates()
#
# ModuleNotFoundError: No module named 'ydata_profiling'

# %%
# %pip install ydata-profiling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 4.0.0 Requires-Python >=3.7,<3.11; 4.1.0 Requires-Python >=3.7,<3.12; 4.1.1 Requires-Python >=3.7,<3.12; 4.1.2 Requires-Python >=3.7,<3.12; 4.10.0 Requires-Python >=3.7,<3.13; 4.11.0 Requires-Python >=3.7,<3.13; 4.12.0 Requires-Python >=3.7,<3.13; 4.12.1 Requires-Python >=3.7,<3.13; 4.12.2 Requires-Python >=3.7,<3.13; 4.13.0 Requires-Python >=3.7,<3.13; 4.14.0 Requires-Python >=3.7,<3.13; 4.15.0 Requires-Python >=3.7,<3.13; 4.15.1 Requires-Python >=3.7,<3.13; 4.16.0 Requires-Python >=3.7,<3.13; 4.16.1 Requires-Python >=3.7,<3.13; 4.17.0 Requires-Python >=3.7,<3.14; 4.18.0 Requires-Python >=3.10,<3.14; 4.18.1 Requires-Python >=3.10,<3.14; 4.18.4 Requires-Python >=3.10,<3.14; 4.2.0 Requires-Python >=3.7,<3.12; 4.3.0 Requires-Python >=3.7,<3.12; 4.3.1 Requires-Python >=3.7,<3.12; 4.3.2 Requires-Python >=3.7,<3.12; 4.4.0 Requires-Python >=3.7,<3.12; 4.5.0 Requires-Python >=3.7,<3.12; 4.5.1 Requires-Python >=3.7,<3.12; 4.6.0 Requires-Python >=3.7,<3.12; 4.6.1 Requires-Python >=3.7,<3.12; 4.6.2 Requires-Python >=3.7,<3.12; 4.6.3 Requires-Python >=3.7,<3.12; 4.6.4 Requires-Python >=3.7,<3.12; 4.6.5 Requires-Python >=3.7,<3.12; 4.7.0 Requires-Python >=3.7,<3.13; 4.8.3 Requires-Python >=3.7,<3.13; 4.9.0 Requires-Python >=3.7,<3.13
# ERROR: Could not find a version that satisfies the requirement ydata-profiling (from versions: none)
# ERROR: No matching distribution found for ydata-profiling
